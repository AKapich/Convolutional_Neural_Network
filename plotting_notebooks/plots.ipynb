# %%
from src.plots import plot_metrics, plot_metric_from_folders

# %% [markdown]
# # Our model architecture comparison

# %%
plot_metrics(
    "./saved_models/ourmodel/ourmodel_20/training_log_ourmodel_2.json",
    metric="accuracy",
)

# %%
plot_metrics(
    "./saved_models/ourmodel/our_model_no_se/training_log_ourmodel_no_se.json",
    metric="accuracy",
)

# %%
plot_metrics(
    "./saved_models/ourmodel/ourmodel_se_8/training_log_ourmodel_se_8.json",
    metric="accuracy",
)

# %%
plot_metrics(
    "./saved_models/vgg_pretrained/horizontal_flip_20/vgg_pretrained.json",
    metric="accuracy",
)

# %%
folders = {
    "./saved_models/ourmodel/ourmodel_noaux/": "no_aux",
    "./saved_models/ourmodel/ourmodel_se_8/": "se_8",
    "./saved_models/ourmodel/our_model_no_se/": "no_se",
    "./saved_models/ourmodel/ourmodel_20/": "se_16",
}
plot_metric_from_folders(folders, metric="accuracy", metric_type="train")
plot_metric_from_folders(folders, metric="accuracy", metric_type="valid")
plot_metric_from_folders(folders, metric="f1-score", metric_type="train")
plot_metric_from_folders(folders, metric="f1-score", metric_type="valid")
plot_metric_from_folders(folders, metric="loss", metric_type="train")
plot_metric_from_folders(folders, metric="loss", metric_type="valid")

# %% [markdown]
# # Our model training parameters comparison

# %%
folders = {
    "./saved_models/ourmodel/adam_01/": "adam_01",
    "./saved_models/ourmodel/adam_001/": "adam_001",
    "./saved_models/ourmodel/adam_0001/": "adam_0001",
    "./saved_models/ourmodel/sgd_01/": "sgd_01",
    "./saved_models/ourmodel/sgd_001/": "sgd_001",
    "./saved_models/ourmodel/sgd_0001/": "sgd_0001",
}
plot_metric_from_folders(folders, metric="accuracy", metric_type="train")
plot_metric_from_folders(folders, metric="accuracy", metric_type="valid")
plot_metric_from_folders(folders, metric="f1-score", metric_type="train")
plot_metric_from_folders(folders, metric="f1-score", metric_type="valid")
plot_metric_from_folders(folders, metric="loss", metric_type="train")
plot_metric_from_folders(folders, metric="loss", metric_type="valid")

# %%
folders = {
    "./saved_models/vgg_pretrained/training_params_adam_01/": "adam_01",
    "./saved_models/vgg_pretrained/training_params_adam_001/": "adam_001",
    "./saved_models/vgg_pretrained/training_params_adam_0001/": "adam_0001",
    "./saved_models/vgg_pretrained/training_params_sgd_01/": "sgd_01",
    "./saved_models/vgg_pretrained/training_params_sgd_001/": "sgd_001",
    "./saved_models/vgg_pretrained/training_params_sgd_0001/": "sgd_0001",
}
plot_metric_from_folders(folders, metric="accuracy", metric_type="train")
plot_metric_from_folders(folders, metric="accuracy", metric_type="valid")
plot_metric_from_folders(folders, metric="f1-score", metric_type="train")
plot_metric_from_folders(folders, metric="f1-score", metric_type="valid")
plot_metric_from_folders(folders, metric="loss", metric_type="train")
plot_metric_from_folders(folders, metric="loss", metric_type="valid")


plot_metrics(
    "./saved_models/vgg_pretrained/training_params_adam_0001/vgg_pretrained_adam_0.0001.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/vgg_pretrained/training_params_adam_001/vgg_pretrained_adam_0.001.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/vgg_pretrained/training_params_adam_01/vgg_pretrained_adam_0.01.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/vgg_pretrained/training_params_sgd_01/vgg_pretrained_sgd_0.01.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/vgg_pretrained/training_params_sgd_001/vgg_pretrained_sgd_0.001.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/vgg_pretrained/training_params_sgd_0001/vgg_pretrained_sgd_0.0001.json",
    metric="accuracy",
)

# %%
folders = {
    "./saved_models/resnet/training_params_adam_01/": "adam_01",
    "./saved_models/resnet/training_params_adam_001/": "adam_001",
    # './saved_models/resnet/training_params_adam_0001/': 'adam_0001',
    "./saved_models/resnet/training_params_sgd_01/": "sgd_01",
    "./saved_models/resnet/training_params_sgd_001/": "sgd_001",
    "./saved_models/resnet/training_params_sgd_0001/": "sgd_0001",
}
plot_metric_from_folders(folders, metric="accuracy", metric_type="train")
plot_metric_from_folders(folders, metric="accuracy", metric_type="valid")
plot_metric_from_folders(folders, metric="f1-score", metric_type="train")
plot_metric_from_folders(folders, metric="f1-score", metric_type="valid")
plot_metric_from_folders(folders, metric="loss", metric_type="train")
plot_metric_from_folders(folders, metric="loss", metric_type="valid")


# plot_metrics('./saved_models/resnet/training_params_adam_0001/resnet_adam_0.0001.json', metric="accuracy")
plot_metrics(
    "./saved_models/resnet/training_params_adam_001/resnet_adam_0.001.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/resnet/training_params_adam_01/resnet_adam_0.01.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/resnet/training_params_sgd_01/resnet_sgd_0.01.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/resnet/training_params_sgd_001/resnet_sgd_0.001.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/resnet/training_params_sgd_0001/resnet_sgd_0.0001.json",
    metric="accuracy",
)

# %% [markdown]
# # Ourmodel regularization parameters

# %%
folders = {
    "./saved_models/ourmodel/w01_d2/": "w01_d2",
    "./saved_models/ourmodel/w001_d2/": "w001_d2",
    "./saved_models/ourmodel/w0001_d2/": "w0001_d2",
    "./saved_models/ourmodel/w01_d5/": "w01_d5",
    "./saved_models/ourmodel/w001_d5/": "w001_d5",
    "./saved_models/ourmodel/w0001_d5/": "w0001_d5",
    "./saved_models/ourmodel/w01_d7/": "w01_d7",
    "./saved_models/ourmodel/w001_d7/": "w001_d7",
    "./saved_models/ourmodel/w0001_d7/": "w0001_d7",
}
plot_metric_from_folders(folders, metric="accuracy", metric_type="train")
plot_metric_from_folders(folders, metric="accuracy", metric_type="valid")
plot_metric_from_folders(folders, metric="f1-score", metric_type="train")
plot_metric_from_folders(folders, metric="f1-score", metric_type="valid")
plot_metric_from_folders(folders, metric="loss", metric_type="train")
plot_metric_from_folders(folders, metric="loss", metric_type="valid")

plot_metrics("./saved_models/ourmodel/w01_d2/ourmodel_01_2.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/w01_d5/ourmodel_01_5.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/w01_d7/ourmodel_01_7.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/w001_d2/ourmodel_001_2.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/w001_d5/ourmodel_001_5.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/w001_d7/ourmodel_001_7.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/w0001_d2/ourmodel_0001_2.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/w0001_d5/ourmodel_0001_5.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/w0001_d7/ourmodel_0001_7.json", metric="accuracy")

# %% [markdown]
# Vgg16 pretrained regularization parametrs

# %%
folders = {
    "./saved_models/vgg_pretrained/regularization_params_01/": "w01",
    "./saved_models/vgg_pretrained/regularization_params_001/": "w001",
    "./saved_models/vgg_pretrained/regularization_params_0001/": "w0001",
}
plot_metric_from_folders(folders, metric="accuracy", metric_type="train")
plot_metric_from_folders(folders, metric="accuracy", metric_type="valid")
plot_metric_from_folders(folders, metric="f1-score", metric_type="train")
plot_metric_from_folders(folders, metric="f1-score", metric_type="valid")
plot_metric_from_folders(folders, metric="loss", metric_type="train")
plot_metric_from_folders(folders, metric="loss", metric_type="valid")

plot_metrics(
    "./saved_models/vgg_pretrained/regularization_params_01/vgg_pretrained_01_5.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/vgg_pretrained/regularization_params_001/vgg_pretrained_001_5.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/vgg_pretrained/regularization_params_0001/vgg_pretrained_0001_5.json",
    metric="accuracy",
)

# %% [markdown]
# # Ourmodel data augmentation

# %%
folders = {
    "./saved_models/ourmodel/rotation/": "rotation",
    "./saved_models/ourmodel/horizontal_flip/": "horizontal_flip",
    "./saved_models/ourmodel/color_jitter/": "color_jitter",
    "./saved_models/ourmodel/combined/": "combined",
    "./saved_models/ourmodel/cutout/": "cutout",
}
plot_metric_from_folders(folders, metric="accuracy", metric_type="train")
plot_metric_from_folders(folders, metric="accuracy", metric_type="valid")
plot_metric_from_folders(folders, metric="f1-score", metric_type="train")
plot_metric_from_folders(folders, metric="f1-score", metric_type="valid")
plot_metric_from_folders(folders, metric="loss", metric_type="train")
plot_metric_from_folders(folders, metric="loss", metric_type="valid")

plot_metrics("./saved_models/ourmodel/rotation/ourmodel.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/horizontal_flip/ourmodel.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/color_jitter/ourmodel.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/combined/ourmodel.json", metric="accuracy")
plot_metrics("./saved_models/ourmodel/cutout/ourmodel.json", metric="accuracy")

# %% [markdown]
# # VGG

# %% [markdown]
# ### Training parameters

# %%
folders = {
    "./saved_models/vgg/training_params_adam_01/": "adam_01",
    "./saved_models/vgg/training_params_adam_001/": "adam_001",
    "./saved_models/vgg/training_params_adam_0001/": "adam_0001",
    "./saved_models/vgg/training_params_sgd_01/": "sgd_01",
    "./saved_models/vgg/training_params_sgd_001/": "sgd_001",
    "./saved_models/vgg/training_params_sgd_0001/": "sgd_0001",
}


metrics = ["accuracy", "f1-score", "loss"]
metric_types = ["train", "valid"]
model_type = "vgg"

for metric in metrics:
    for metric_type in metric_types:
        fig = plot_metric_from_folders(folders, metric=metric, metric_type=metric_type)
        fig_path = f"./images/{model_type}/{model_type}_training_params_{metric}_{metric_type}.png"
        fig.savefig(fig_path, bbox_inches="tight", dpi=300)
        print(f"Saved {fig_path}")
# Out:
# Saved ./images/vgg/vgg_training_params_accuracy_train.png
# Saved ./images/vgg/vgg_training_params_accuracy_valid.png
# Saved ./images/vgg/vgg_training_params_f1-score_train.png
# Saved ./images/vgg/vgg_training_params_f1-score_valid.png
# Saved ./images/vgg/vgg_training_params_loss_train.png
# Saved ./images/vgg/vgg_training_params_loss_valid.png

# %%
model_type = "vgg"
log_files = [
    "./saved_models/vgg/training_params_adam_0001/vgg_pretrained_adam_0.0001.json",
    "./saved_models/vgg/training_params_adam_001/vgg_pretrained_adam_0.001.json",
    "./saved_models/vgg/training_params_adam_01/vgg_pretrained_adam_0.01.json",
    "./saved_models/vgg/training_params_sgd_01/vgg_pretrained_sgd_0.01.json",
    "./saved_models/vgg/training_params_sgd_001/vgg_pretrained_sgd_0.001.json",
    "./saved_models/vgg/training_params_sgd_0001/vgg_pretrained_sgd_0.0001.json",
]

for log_file in log_files:
    optimizer = "adam" if "adam" in log_file else "sgd"
    lr_value = log_file.split("_")[-1].replace(".json", "")

    fig = plot_metrics(log_file, metric="accuracy")
    fig_path = f"./images/{model_type}/{model_type}_accuracy_{optimizer}_{lr_value}.png"
    fig.savefig(fig_path, bbox_inches="tight", dpi=300)
    print(f"Saved {fig_path}")
# Out:
# Saved ./images/vgg/vgg_accuracy_adam_0.0001.png
# Saved ./images/vgg/vgg_accuracy_adam_0.001.png
# Saved ./images/vgg/vgg_accuracy_adam_0.01.png
# Saved ./images/vgg/vgg_accuracy_sgd_0.01.png
# Saved ./images/vgg/vgg_accuracy_sgd_0.001.png
# Saved ./images/vgg/vgg_accuracy_sgd_0.0001.png

# %% [markdown]
# ### Regularization parameters

# %%
folders = {
    "./saved_models/vgg/regularization_params_01/": "decay_01",
    "./saved_models/vgg/regularization_params_001/": "decay_001",
    "./saved_models/vgg/regularization_params_0001/": "decay_0001",
}


metrics = ["accuracy", "f1-score", "loss"]
metric_types = ["train", "valid"]
model_type = "vgg"

for metric in metrics:
    for metric_type in metric_types:
        fig = plot_metric_from_folders(folders, metric=metric, metric_type=metric_type)
        fig_path = f"./images/{model_type}/{model_type}_regularization_params_{metric}_{metric_type}.png"
        fig.savefig(fig_path, bbox_inches="tight", dpi=300)
        print(f"Saved {fig_path}")
# Out:
# Saved ./images/vgg/vgg_regularization_params_accuracy_train.png
# Saved ./images/vgg/vgg_regularization_params_accuracy_valid.png
# Saved ./images/vgg/vgg_regularization_params_f1-score_train.png
# Saved ./images/vgg/vgg_regularization_params_f1-score_valid.png
# Saved ./images/vgg/vgg_regularization_params_loss_train.png
# Saved ./images/vgg/vgg_regularization_params_loss_valid.png

# %% [markdown]
# ### Data augmentation

# %%
folders = {
    "./saved_models/vgg_pretrained/rotation/": "rotation",
    "./saved_models/vgg_pretrained/horizontal_flip/": "horizontal_flip",
    "./saved_models/vgg_pretrained/color_jitter/": "color_jitter",
    "./saved_models/vgg_pretrained/combined/": "combined",
    "./saved_models/vgg_pretrained/cutout/": "cutout",
}
plot_metric_from_folders(folders, metric="accuracy", metric_type="train")
plot_metric_from_folders(folders, metric="accuracy", metric_type="valid")
plot_metric_from_folders(folders, metric="f1-score", metric_type="train")
plot_metric_from_folders(folders, metric="f1-score", metric_type="valid")
plot_metric_from_folders(folders, metric="loss", metric_type="train")
plot_metric_from_folders(folders, metric="loss", metric_type="valid")

plot_metrics(
    "./saved_models/vgg_pretrained/rotation/vgg_pretrained.json", metric="accuracy"
)
plot_metrics(
    "./saved_models/vgg_pretrained/horizontal_flip/vgg_pretrained.json",
    metric="accuracy",
)
plot_metrics(
    "./saved_models/vgg_pretrained/color_jitter/vgg_pretrained.json", metric="accuracy"
)
plot_metrics(
    "./saved_models/vgg_pretrained/combined/vgg_pretrained.json", metric="accuracy"
)
plot_metrics(
    "./saved_models/vgg_pretrained/cutout/vgg_pretrained.json", metric="accuracy"
)

# %%
folders = {
    "./saved_models/vgg/augmented/rotation/": "rotation",
    "./saved_models/vgg/augmented/flip/": "flip",
    "./saved_models/vgg/augmented/jitter/": "color_jitter",
    "./saved_models/vgg/augmented/cutout/": "cutout",
    "./saved_models/vgg/augmented/combined/": "combined",
}


metrics = ["accuracy", "f1-score", "loss"]
metric_types = ["train", "valid"]
model_type = "vgg"

for metric in metrics:
    for metric_type in metric_types:
        fig = plot_metric_from_folders(folders, metric=metric, metric_type=metric_type)
        fig_path = f"./images/{model_type}/aug/{model_type}_augmentation_{metric}_{metric_type}.png"
        fig.savefig(fig_path, bbox_inches="tight", dpi=300)
        print(f"Saved {fig_path}")
# Out:
# Saved ./images/vgg/aug/vgg_augmentation_accuracy_train.png
# Saved ./images/vgg/aug/vgg_augmentation_accuracy_valid.png
# Saved ./images/vgg/aug/vgg_augmentation_f1-score_train.png
# Saved ./images/vgg/aug/vgg_augmentation_f1-score_valid.png
# Saved ./images/vgg/aug/vgg_augmentation_loss_train.png
# Saved ./images/vgg/aug/vgg_augmentation_loss_valid.png

# %%
model_type = "vgg"
log_files = [
    "./saved_models/vgg/augmented/combined/vgg_combined.json",
    "./saved_models/vgg/augmented/flip/vgg_flip.json",
    "./saved_models/vgg/augmented/rotation/vgg_rotated.json",
    "./saved_models/vgg/augmented/jitter/vgg_jitter.json",
    "./saved_models/vgg/augmented/cutout/vgg_cutout.json",
]

for log_file in log_files:
    augmentation = log_file.split("/")[-2]

    fig = plot_metrics(log_file, metric="f1-score")
    fig_path = f"./images/{model_type}/aug/{model_type}_f1_{augmentation}.png"
    fig.savefig(fig_path, bbox_inches="tight", dpi=300)
    print(f"Saved {fig_path}")
# Out:
# Saved ./images/vgg/aug/vgg_f1_combined.png
# Saved ./images/vgg/aug/vgg_f1_flip.png
# Saved ./images/vgg/aug/vgg_f1_rotation.png
# Saved ./images/vgg/aug/vgg_f1_jitter.png
# Saved ./images/vgg/aug/vgg_f1_cutout.png

# %% [markdown]
# # ResNet

# %% [markdown]
# ### Training parameters

# %%
folders = {
    "./saved_models/resnet/training_params_adam_01/": "adam_01",
    "./saved_models/resnet/training_params_adam_001/": "adam_001",
    "./saved_models/resnet/training_params_adam_0001/": "adam_0001",
    "./saved_models/resnet/training_params_sgd_01/": "sgd_01",
    "./saved_models/resnet/training_params_sgd_001/": "sgd_001",
    "./saved_models/resnet/training_params_sgd_0001/": "sgd_0001",
}


metrics = ["accuracy", "f1-score", "loss"]
metric_types = ["train", "valid"]
model_type = "resnet"

for metric in metrics:
    for metric_type in metric_types:
        fig = plot_metric_from_folders(folders, metric=metric, metric_type=metric_type)
        fig_path = f"./images/{model_type}/{model_type}_training_params_{metric}_{metric_type}.png"
        fig.savefig(fig_path, bbox_inches="tight", dpi=300)
        print(f"Saved {fig_path}")
# Out:
# Saved ./images/resnet/resnet_training_params_accuracy_train.png
# Saved ./images/resnet/resnet_training_params_accuracy_valid.png
# Saved ./images/resnet/resnet_training_params_f1-score_train.png
# Saved ./images/resnet/resnet_training_params_f1-score_valid.png
# Saved ./images/resnet/resnet_training_params_loss_train.png
# Saved ./images/resnet/resnet_training_params_loss_valid.png

# %%
model_type = "resnet"
log_files = [
    "./saved_models/resnet/training_params_adam_0001/resnet_adam_0.0001.json",
    "./saved_models/resnet/training_params_adam_001/resnet_adam_0.001.json",
    "./saved_models/resnet/training_params_adam_01/resnet_adam_0.01.json",
    "./saved_models/resnet/training_params_sgd_01/resnet_sgd_0.01.json",
    "./saved_models/resnet/training_params_sgd_001/resnet_sgd_0.001.json",
    "./saved_models/resnet/training_params_sgd_0001/resnet_sgd_0.0001.json",
]

for log_file in log_files:
    optimizer = "adam" if "adam" in log_file else "sgd"
    lr_value = log_file.split("_")[-1].replace(".json", "")

    fig = plot_metrics(log_file, metric="f1-score")
    fig_path = f"./images/{model_type}/{model_type}_f1_{optimizer}_{lr_value}.png"
    fig.savefig(fig_path, bbox_inches="tight", dpi=300)
    print(f"Saved {fig_path}")
# Out:
# Saved ./images/resnet/resnet_f1_adam_0.0001.png
# Saved ./images/resnet/resnet_f1_adam_0.001.png
# Saved ./images/resnet/resnet_f1_adam_0.01.png
# Saved ./images/resnet/resnet_f1_sgd_0.01.png
# Saved ./images/resnet/resnet_f1_sgd_0.001.png
# Saved ./images/resnet/resnet_f1_sgd_0.0001.png

# %% [markdown]
# ### Regularization parameters

# %%
folders = {
    "./saved_models/resnet/decay01/": "decay_01",
    "./saved_models/resnet/decay001/": "decay_001",
    "./saved_models/resnet/decay0001/": "decay_0001",
}


metrics = ["accuracy", "f1-score", "loss"]
metric_types = ["train", "valid"]
model_type = "resnet"

for metric in metrics:
    for metric_type in metric_types:
        fig = plot_metric_from_folders(folders, metric=metric, metric_type=metric_type)
        fig_path = f"./images/{model_type}/{model_type}_regularization_params_{metric}_{metric_type}.png"
        fig.savefig(fig_path, bbox_inches="tight", dpi=300)
        print(f"Saved {fig_path}")
# Out:
# Saved ./images/resnet/resnet_regularization_params_accuracy_train.png
# Saved ./images/resnet/resnet_regularization_params_accuracy_valid.png
# Saved ./images/resnet/resnet_regularization_params_f1-score_train.png
# Saved ./images/resnet/resnet_regularization_params_f1-score_valid.png
# Saved ./images/resnet/resnet_regularization_params_loss_train.png
# Saved ./images/resnet/resnet_regularization_params_loss_valid.png

# %% [markdown]
# ### Data augmentation

# %%
folders = {
    "./saved_models/resnet/training_params_adam_01/": "adam_01",
    "./saved_models/resnet/training_params_adam_001/": "adam_001",
    "./saved_models/resnet/training_params_adam_0001/": "adam_0001",
    "./saved_models/resnet/training_params_sgd_01/": "sgd_01",
    "./saved_models/resnet/training_params_sgd_001/": "sgd_001",
    "./saved_models/resnet/training_params_sgd_0001/": "sgd_0001",
}


metrics = ["accuracy", "f1-score", "loss"]
metric_types = ["train", "valid"]
model_type = "resnet"

for metric in metrics:
    for metric_type in metric_types:
        fig = plot_metric_from_folders(folders, metric=metric, metric_type=metric_type)
        fig_path = f"./images/{model_type}/{model_type}_training_params_{metric}_{metric_type}.png"
        fig.savefig(fig_path, bbox_inches="tight", dpi=300)
        print(f"Saved {fig_path}")

# %%
model_type = "resnet"
log_files = [
    "./saved_models/resnet/augmented/combined/resnet_combined.json",
    "./saved_models/resnet/augmented/flip/resnet_flip.json",
    "./saved_models/resnet/augmented/rotation/resnet_rotated.json",
    "./saved_models/resnet/augmented/jitter/resnet_jitter.json",
    "./saved_models/resnet/augmented/cutout/resnet_cutout.json",
]

for log_file in log_files:
    augmentation = log_file.split("/")[-2]

    fig = plot_metrics(log_file, metric="f1-score")
    fig_path = f"./images/{model_type}/aug/{model_type}_f1_{augmentation}.png"
    fig.savefig(fig_path, bbox_inches="tight", dpi=300)
    print(f"Saved {fig_path}")
# Out:
# Saved ./images/resnet/aug/resnet_f1_combined.png
# Saved ./images/resnet/aug/resnet_f1_flip.png
# Saved ./images/resnet/aug/resnet_f1_rotation.png
# Saved ./images/resnet/aug/resnet_f1_jitter.png
# Saved ./images/resnet/aug/resnet_f1_cutout.png

# %% [markdown]
# # Custom

# %% [markdown]
# ### Training parameters

# %%
folders = {
    "./saved_models/ourmodel/adam_01/": "adam_01",
    "./saved_models/ourmodel/adam_001/": "adam_001",
    "./saved_models/ourmodel/adam_0001/": "adam_0001",
    "./saved_models/ourmodel/sgd_01/": "sgd_01",
    "./saved_models/ourmodel/sgd_001/": "sgd_001",
    "./saved_models/ourmodel/sgd_0001/": "sgd_0001",
}


metrics = ["accuracy", "f1-score", "loss"]
metric_types = ["train", "valid"]
model_type = "custom"

for metric in metrics:
    for metric_type in metric_types:
        fig = plot_metric_from_folders(folders, metric=metric, metric_type=metric_type)
        fig_path = f"./images/{model_type}/{model_type}_training_params_{metric}_{metric_type}.png"
        fig.savefig(fig_path, bbox_inches="tight", dpi=300)
        print(f"Saved {fig_path}")
# Out:
# Saved ./images/custom/custom_training_params_accuracy_train.png
# Saved ./images/custom/custom_training_params_accuracy_valid.png
# Saved ./images/custom/custom_training_params_f1-score_train.png
# Saved ./images/custom/custom_training_params_f1-score_valid.png
# Saved ./images/custom/custom_training_params_loss_train.png
# Saved ./images/custom/custom_training_params_loss_valid.png

# %% [markdown]
# ### Data augmentation

# %%
model_type = "custom"
log_files = [
    "./saved_models/ourmodel/augmented/combined/ourmodel_combined.json",
    "./saved_models/ourmodel/augmented/flip/ourmodel_flip.json",
    "./saved_models/ourmodel/augmented/rotation/ourmodel_rotated.json",
    "./saved_models/ourmodel/augmented/jitter/ourmodel_jitter.json",
    "./saved_models/ourmodel/augmented/cutout/ourmodel_cutout.json",
]

for log_file in log_files:
    augmentation = log_file.split("/")[-2]

    fig = plot_metrics(log_file, metric="f1-score")
    fig_path = f"./images/{model_type}/aug/{model_type}_f1_{augmentation}.png"
    fig.savefig(fig_path, bbox_inches="tight", dpi=300)
    print(f"Saved {fig_path}")
# Out:
# Saved ./images/custom/aug/custom_f1_combined.png
# Saved ./images/custom/aug/custom_f1_flip.png
# Saved ./images/custom/aug/custom_f1_rotation.png
# Saved ./images/custom/aug/custom_f1_jitter.png
# Saved ./images/custom/aug/custom_f1_cutout.png
