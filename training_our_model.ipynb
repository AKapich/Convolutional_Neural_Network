# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
os.chdir('drive/MyDrive')

# %%
os.listdir('src')
# Out:
# ['transformations.py', 'utils.py', 'model_trainer.py', 'models', '__pycache__']

# %%
from src.models.our_model1 import OurModelSmall, OurModelBig, OurModel
from src.utils import load_data
import torch
from src.utils import load_data, evaluate_model
from src.model_trainer import ModelTrainer
from torchsummary import summary
from src.transformations import normalized_simple_transform
torch.manual_seed(123)
from src.model_trainer import ModelTrainer

# %%
device_str = "cuda" if torch.cuda.is_available() else "cpu"
device = torch.device(device_str)
print(device)
torch.set_num_threads(2)
# Out:
# cuda

# %%
# cell for donwloading data

# import os
# import tarfile
# import urllib.request
# import shutil

# download_dir = "/data"

# if not os.path.exists(download_dir):
#     os.makedirs(download_dir)

# tar_path = os.path.join(download_dir, "CINIC-10.tar.gz")
# cinic10_url = "https://datashare.is.ed.ac.uk/bitstream/handle/10283/3192/CINIC-10.tar.gz"
# urllib.request.urlretrieve(cinic10_url, tar_path)
# print("Finished downloading")

# with tarfile.open(tar_path, "r:gz") as tar:
#     tar.extractall(path=download_dir)

# extracted_dir = os.path.join(download_dir, "CINIC-10")

# if os.path.exists(extracted_dir) and os.path.isdir(extracted_dir):
#     for item in os.listdir(extracted_dir):
#         src_path = os.path.join(extracted_dir, item)
#         dst_path = os.path.join(download_dir, item)
#         shutil.move(src_path, dst_path)

# print(download_dir)

# %%
test_loader = load_data('/data/test', batch_size=128, shuffle=True, transform=normalized_simple_transform(), num_workers=1)
train_loader = load_data('/data/train', batch_size=128, shuffle=True, transform=normalized_simple_transform(), num_workers=1)
valid_loader = load_data('/data/valid', batch_size=128, shuffle=True, transform=normalized_simple_transform(), num_workers=1)

# %%
model = OurModel()

# %%
# trainer = ModelTrainer(
#         model=model,
#         train_loader=train_loader,
#         device=device,
#         optimizer_type='adam',
#         learning_rate=0.001,
#         log_file='training_log_ourmodel.json',
#         save_dir=f'/saved_models/ourmodel',
#         max_batches = None,
#         valid_loader=valid_loader
#     )

# %%
# trainer.train(epochs=10)
# Out:
# <ipython-input-6-45d2e6d38afe>:115: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if self.device.type == 'cuda' else None
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 0
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 1/10, Loss: 1.6815, Accuracy: 0.5254, F1-score: 0.5217
# Model saved to /saved_models/ourmodel/OurModel_1.pth
# Batch count validation 0
# <ipython-input-6-45d2e6d38afe>:206: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count validation 100
# Batch count validation 200
# Batch count validation 300
# Batch count validation 400
# Batch count validation 500
# Batch count validation 600
# Batch count validation 700
# Valid Loss: 1.5854, Accuracy: 0.5584, F1-score: 0.5413
# Training log saved to /saved_models/ourmodel/training_log_ourmodel.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 2/10, Loss: 1.6274, Accuracy: 0.5330, F1-score: 0.5282
# Model saved to /saved_models/ourmodel/OurModel_2.pth
# Batch count validation 0
# <ipython-input-6-45d2e6d38afe>:206: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count validation 100
# Batch count validation 200
# Batch count validation 300
# Batch count validation 400
# Batch count validation 500
# Batch count validation 600
# Batch count validation 700
# Valid Loss: 1.4794, Accuracy: 0.5813, F1-score: 0.5828
# Training log saved to /saved_models/ourmodel/training_log_ourmodel.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 3/10, Loss: 1.2446, Accuracy: 0.6515, F1-score: 0.6496
# Model saved to /saved_models/ourmodel/OurModel_3.pth
# Batch count validation 0
# <ipython-input-6-45d2e6d38afe>:206: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count validation 100
# Batch count validation 200
# Batch count validation 300
# Batch count validation 400
# Batch count validation 500
# Batch count validation 600
# Batch count validation 700
# Valid Loss: 1.2258, Accuracy: 0.6619, F1-score: 0.6606
# Training log saved to /saved_models/ourmodel/training_log_ourmodel.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 4/10, Loss: 1.1165, Accuracy: 0.6900, F1-score: 0.6885
# Model saved to /saved_models/ourmodel/OurModel_4.pth
# Batch count validation 0
# <ipython-input-6-45d2e6d38afe>:206: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count validation 100
# Batch count validation 200
# Batch count validation 300
# Batch count validation 400
# Batch count validation 500
# Batch count validation 600
# Batch count validation 700
# Valid Loss: 1.1750, Accuracy: 0.6793, F1-score: 0.6738
# Training log saved to /saved_models/ourmodel/training_log_ourmodel.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 5/10, Loss: 1.0067, Accuracy: 0.7207, F1-score: 0.7193
# Model saved to /saved_models/ourmodel/OurModel_5.pth
# Batch count validation 0
# <ipython-input-6-45d2e6d38afe>:206: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count validation 100
# Batch count validation 200
# Batch count validation 300
# Batch count validation 400
# Batch count validation 500
# Batch count validation 600
# Batch count validation 700
# Valid Loss: 1.1274, Accuracy: 0.6919, F1-score: 0.6875
# Training log saved to /saved_models/ourmodel/training_log_ourmodel.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 6/10, Loss: 0.9259, Accuracy: 0.7416, F1-score: 0.7405
# Model saved to /saved_models/ourmodel/OurModel_6.pth
# Batch count validation 0
# <ipython-input-6-45d2e6d38afe>:206: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count validation 100
# Batch count validation 200
# Batch count validation 300
# Batch count validation 400
# Batch count validation 500
# Batch count validation 600
# Batch count validation 700
# Valid Loss: 1.0859, Accuracy: 0.7055, F1-score: 0.7057
# Training log saved to /saved_models/ourmodel/training_log_ourmodel.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 7/10, Loss: 0.8429, Accuracy: 0.7639, F1-score: 0.7629
# Model saved to /saved_models/ourmodel/OurModel_7.pth
# Batch count validation 0
# <ipython-input-6-45d2e6d38afe>:206: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count validation 100
# Batch count validation 200
# Batch count validation 300
# Batch count validation 400
# Batch count validation 500
# Batch count validation 600
# Batch count validation 700
# Valid Loss: 1.0475, Accuracy: 0.7275, F1-score: 0.7279
# Training log saved to /saved_models/ourmodel/training_log_ourmodel.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 8/10, Loss: 0.7719, Accuracy: 0.7823, F1-score: 0.7814
# Model saved to /saved_models/ourmodel/OurModel_8.pth
# Batch count validation 0
# <ipython-input-6-45d2e6d38afe>:206: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count validation 100
# Batch count validation 200
# Batch count validation 300
# Batch count validation 400
# Batch count validation 500
# Batch count validation 600
# Batch count validation 700
# Valid Loss: 1.0959, Accuracy: 0.7103, F1-score: 0.7109
# Training log saved to /saved_models/ourmodel/training_log_ourmodel.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 9/10, Loss: 0.7009, Accuracy: 0.8002, F1-score: 0.7995
# Model saved to /saved_models/ourmodel/OurModel_9.pth
# Batch count validation 0
# <ipython-input-6-45d2e6d38afe>:206: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count validation 100
# Batch count validation 200
# Batch count validation 300
# Batch count validation 400
# Batch count validation 500
# Batch count validation 600
# Batch count validation 700
# Valid Loss: 1.0814, Accuracy: 0.7245, F1-score: 0.7194
# Training log saved to /saved_models/ourmodel/training_log_ourmodel.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 10/10, Loss: 0.6349, Accuracy: 0.8182, F1-score: 0.8176
# Model saved to /saved_models/ourmodel/OurModel_10.pth
# Batch count validation 0
# <ipython-input-6-45d2e6d38afe>:206: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count validation 100
# Batch count validation 200
# Batch count validation 300
# Batch count validation 400
# Batch count validation 500
# Batch count validation 600
# Batch count validation 700
# Valid Loss: 1.0788, Accuracy: 0.7333, F1-score: 0.7317
# Training log saved to /saved_models/ourmodel/training_log_ourmodel.json

# %%
trainer = ModelTrainer(
        model=model,
        train_loader=train_loader,
        device=device,
        optimizer_type='adam',
        learning_rate=0.001,
        log_file='training_log_ourmodel_2.json',
        save_dir=f'/saved_models/ourmodel_2',
        max_batches = None,
        valid_loader=valid_loader
    )

# %%
trainer.train(epochs=20)
# Out:
# <ipython-input-6-45d2e6d38afe>:115: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler() if self.device.type == 'cuda' else None
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 1/10, Loss: 1.7376, Accuracy: 0.5082, F1-score: 0.5042
# Model saved to /saved_models/ourmodel_2/OurModel_1.pth
# Training log saved to /saved_models/ourmodel_2/training_log_ourmodel_2.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 2/10, Loss: 1.3469, Accuracy: 0.6299, F1-score: 0.6281
# Model saved to /saved_models/ourmodel_2/OurModel_2.pth
# Training log saved to /saved_models/ourmodel_2/training_log_ourmodel_2.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 3/10, Loss: 1.1756, Accuracy: 0.6849, F1-score: 0.6837
# Model saved to /saved_models/ourmodel_2/OurModel_3.pth
# Training log saved to /saved_models/ourmodel_2/training_log_ourmodel_2.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 4/10, Loss: 1.0547, Accuracy: 0.7171, F1-score: 0.7161
# Model saved to /saved_models/ourmodel_2/OurModel_4.pth
# Training log saved to /saved_models/ourmodel_2/training_log_ourmodel_2.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 5/10, Loss: 0.9672, Accuracy: 0.7439, F1-score: 0.7431
# Model saved to /saved_models/ourmodel_2/OurModel_5.pth
# Training log saved to /saved_models/ourmodel_2/training_log_ourmodel_2.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 6/10, Loss: 0.8905, Accuracy: 0.7648, F1-score: 0.7641
# Model saved to /saved_models/ourmodel_2/OurModel_6.pth
# Training log saved to /saved_models/ourmodel_2/training_log_ourmodel_2.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 7/10, Loss: 0.8187, Accuracy: 0.7860, F1-score: 0.7854
# Model saved to /saved_models/ourmodel_2/OurModel_7.pth
# Training log saved to /saved_models/ourmodel_2/training_log_ourmodel_2.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 8/10, Loss: 0.7588, Accuracy: 0.8029, F1-score: 0.8023
# Model saved to /saved_models/ourmodel_2/OurModel_8.pth
# Training log saved to /saved_models/ourmodel_2/training_log_ourmodel_2.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 9/10, Loss: 0.6974, Accuracy: 0.8206, F1-score: 0.8201
# Model saved to /saved_models/ourmodel_2/OurModel_9.pth
# Training log saved to /saved_models/ourmodel_2/training_log_ourmodel_2.json
# Batch count 0
# <ipython-input-6-45d2e6d38afe>:135: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast():
# Batch count 10
# Batch count 20
# Batch count 30
# Batch count 40
# Batch count 50
# Batch count 60
# Batch count 70
# Batch count 80
# Batch count 90
# Batch count 100
# Batch count 110
# Batch count 120
# Batch count 130
# Batch count 140
# Batch count 150
# Batch count 160
# Batch count 170
# Batch count 180
# Batch count 190
# Batch count 200
# Batch count 210
# Batch count 220
# Batch count 230
# Batch count 240
# Batch count 250
# Batch count 260
# Batch count 270
# Batch count 280
# Batch count 290
# Batch count 300
# Batch count 310
# Batch count 320
# Batch count 330
# Batch count 340
# Batch count 350
# Batch count 360
# Batch count 370
# Batch count 380
# Batch count 390
# Batch count 400
# Batch count 410
# Batch count 420
# Batch count 430
# Batch count 440
# Batch count 450
# Batch count 460
# Batch count 470
# Batch count 480
# Batch count 490
# Batch count 500
# Batch count 510
# Batch count 520
# Batch count 530
# Batch count 540
# Batch count 550
# Batch count 560
# Batch count 570
# Batch count 580
# Batch count 590
# Batch count 600
# Batch count 610
# Batch count 620
# Batch count 630
# Batch count 640
# Batch count 650
# Batch count 660
# Batch count 670
# Batch count 680
# Batch count 690
# Batch count 700
# Epoch 10/10, Loss: 0.6447, Accuracy: 0.8362, F1-score: 0.8358
# Model saved to /saved_models/ourmodel_2/OurModel_10.pth
# Training log saved to /saved_models/ourmodel_2/training_log_ourmodel_2.json
